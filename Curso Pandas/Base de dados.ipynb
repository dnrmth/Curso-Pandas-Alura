# %% [markdown]
# # Relatório de Análise I

# %% [markdown]
# ## Importando a Base de Dados

# %%
import pandas as pd

# %%
pd.read_csv('dados/aluguel.csv', sep = ';')
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# ...

# %%
dados = pd.read_csv('dados/aluguel.csv', sep=';', index_col=0)

# %%
dados
# Out:
#                                        Bairro  Quartos  Vagas  Suites  Area  \
# Tipo
# Quitinete                          Copacabana        1      0       0    40
# Casa                          Jardim Botânico        2      0       1   100
# Conjunto Comercial/Sala       Barra da Tijuca        0      4       0   150
# Apartamento                            Centro        1      0       0    15
# Apartamento                      Higienópolis        1      0       0    48
# ...                                       ...      ...    ...     ...   ...
# Quitinete                              Centro        0      0       0    27
# Apartamento                       Jacarepaguá        3      1       2    78
# Apartamento              São Francisco Xavier        2      1       0    48
# Apartamento                            Leblon        2      0       0    70
# Conjunto Comercial/Sala                Centro        0      0       0   250
#
# ...

# %%
type(dados)
# Out:
# pandas.core.frame.DataFrame

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32960 entries, 0 to 32959
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        32960 non-null  object
#  1   Bairro      32960 non-null  object
#  2   Quartos     32960 non-null  int64
#  3   Vagas       32960 non-null  int64
#  4   Suites      32960 non-null  int64
#  5   Area        32960 non-null  int64
#  6   Valor       32943 non-null  float64
#  7   Condominio  28867 non-null  float64
#  8   IPTU        22723 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 2.3+ MB

# %%
dados.head(10)
# Out:
#                                   Bairro  Quartos  Vagas  Suites  Area  \
# Tipo
# Quitinete                     Copacabana        1      0       0    40
# Casa                     Jardim Botânico        2      0       1   100
# Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# Apartamento                       Centro        1      0       0    15
# Apartamento                 Higienópolis        1      0       0    48
# Apartamento                 Vista Alegre        3      1       0    70
# Apartamento                     Cachambi        2      0       0    50
# Casa de Condomínio       Barra da Tijuca        5      4       5   750
# Casa de Condomínio                 Ramos        2      2       0    65
# Conjunto Comercial/Sala           Centro        0      3       0   695
#
#                            Valor  Condominio    IPTU
# Tipo
# Quitinete                 1700.0       500.0    60.0
# Casa                      7000.0         NaN     NaN
# ...

# %% [markdown]
# ## informações gerais sobre a base de dados

# %%
dados.dtypes
# Out:
# Bairro         object
# Quartos         int64
# Vagas           int64
# Suites          int64
# Area            int64
# Valor         float64
# Condominio    float64
# IPTU          float64
# dtype: object

# %%
tipos_de_dados = pd.DataFrame(dados.dtypes, columns = ['Tipos de Dados'])

# %%
tipos_de_dados.columns.name = 'Variáveis'

# %%
tipos_de_dados
# Out:
# Váriaveis  Tipos de Dados
# Bairro             object
# Quartos             int64
# Vagas               int64
# Suites              int64
# Area                int64
# Valor             float64
# Condominio        float64
# IPTU              float64

# %%
dados.shape
# Out:
# (32960, 8)

# %%
dados.shape[0]
# Out:
# 32960

# %%
dados.shape[1]
# Out:
# 8

# %%
print('A base de dados apresenta {} registros (imóveis) e {} variáveis.'.format(dados.shape[0], dados.shape[1]))
# Out:
# A base de dados apresenta 32960 registros (imóveis) e 8 variáveis.

# %% [markdown]
# ## Importando bibliotecas para continuar a aula

# %%
import requests
from bs4 import BeautifulSoup

# %%
url='https://www.federalreserve.gov/releases/h3/current/default.htm'
responde = requests.get(url)
html = responde.content
soup = BeautifulSoup(html, 'html.parser')
table = soup.findAll('table')
html_file = f'<html><body>{table}</body></html>'
